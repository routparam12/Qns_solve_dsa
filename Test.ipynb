# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Qns_solve_dsa/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
T = int(input())
N,M,K = map(int, input().split())
for i in range (T):
  if K *  M >= N:
    print("Yes")
  elif K * M % N == 0:
    print("Yes")
  else:
    print("No")
# Out:
# 3
# 100 100 1
# Yes
# Yes
# Yes

# %%
a,c = map(int,input().split())
b = (a+c)/2
if b.is_integer():
  print(int(b))
else:
  print(-1)
# Out:
# 6 6
# 6

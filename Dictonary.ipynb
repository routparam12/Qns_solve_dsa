# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Qns_solve_dsa/blob/main/Dictonary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dictonary

# %%
chai_types = {"Masala":"Spicy","Ginger":"Zesty","Green":"Mild"}
chai_types
chai_types["Masala"]
# Out:
# 'Spicy'

# %%
chai_types.get("Ginger")
# Out:
# 'Zesty'

# %%
chai_types["Green"]="Fresh"
chai_types.pop("green")
# Out:
# 'Fresh'

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Fresh'}

# %%
for chai in chai_types:
  print(chai,chai_types[chai])
# Out:
# Masala Spicy
# Ginger Zesty
# Green Fresh

# %%
for key,value in chai_types.items():
  print(key,value)
# Out:
# Masala Spicy
# Ginger Zesty
# Green Fresh

# %%
if "Masala" in chai_types:
  print("I have masala tea")
# Out:
# I have masala tea

# %%
print(len(chai_types))
# Out:
# 3

# %%
chai_types["Earl grey"]="Citrus"
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Fresh', 'Earl grey': 'Citrus'}

# %%
chai_types.popitem()
# Out:
# ('Earl grey', 'Citrus')

# %%
chai_types["Green"]
# Out:
# 'Fresh'

# %%
chai_types_copy = chai_types.copy()
chai_types_copy
# Out:
# {'Masala': 'Spicy', 'Ginger': 'Zesty', 'Green': 'Fresh'}

# %%
tea_shop={
    "Chai":{"Masala":"Spicy","Green":"Mild"},
    "Tea":{"Masala":"Spicy","Ginger":"Zesty"}
}
tea_shop
# Out:
# {'Chai': {'Masala': 'Spicy', 'Green': 'Mild'},
#  'Tea': {'Masala': 'Spicy', 'Ginger': 'Zesty'}}

# %%
tea_shop["Chai"]["Green"]
# Out:
# 'Mild'

# %%
Squared_num={x:x**2 for x in range (6)}
Squared_num
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
Squared_num.clear()

# %%
key ={"Masala","Ginger","Lemon"}
key
# Out:
# {'Ginger', 'Lemon', 'Masala'}

# %%
default_value = "Delicious"
new_dictonary = dict.fromkeys(key, default_value)
new_dictonary
# Out:
# {'Ginger': 'Delicious', 'Masala': 'Delicious', 'Lemon': 'Delicious'}

# %%
default_value = dict.fromkeys(key,key)
default_value
# Out:
# {'Ginger': {'Ginger', 'Lemon', 'Masala'},
#  'Masala': {'Ginger', 'Lemon', 'Masala'},
#  'Lemon': {'Ginger', 'Lemon', 'Masala'}}

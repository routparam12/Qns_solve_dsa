# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Qns_solve_dsa/blob/main/Error%20Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open('Filename.txt','w')

# %%
try:
  file.write("Chai aur code")
finally:
  file.close()

# %%
with open('Filename.txt','w') as file:
    file.write("Chai aur code")

# %%
def list_all_videos(videos):
  print("List all")


while True:
  print("Manager")
  print("List all")
  print("update details")
  print("Delete un-necessary video")
  print("Exit the app")
  choice = int(input("Enter your choice: "))
  match choice:
    case 1:
      print("List all")
# Out:
# Manager
# List all
# update details
# Delete un-necessary video
# Exit the app
# Enter your choice: h
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2394/2252314186.py in <cell line: 0>()
#       9   print("Delete un-necessary video")
#      10   print("Exit the app")
# ---> 11   choice = int(input("Enter your choice: "))
#      12   match choice:
#      13     case 1:
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
file = open('test.py','w')
try:
  file.write('Param aur code')
finally:
  file.close()

with open('test.py','w') as file:
  file.write('chai & python')

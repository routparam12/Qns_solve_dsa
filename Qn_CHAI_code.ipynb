# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Qns_solve_dsa/blob/main/Qn_CHAI_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a car class with attributes like brand and module . Then create an instance of this class.

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

my_car = Car("Toyota","Corolla")
print(my_car.brand)
print(my_car.model)

new_car = Car("\nHonda","Civic")
print(new_car.brand)
print(new_car.model)
# Out:
# Toyota
# Corolla
#
# Honda
# Civic

# %% [markdown]
# #Class method and self
# Add a method to the car class that displays the full name of the car (brand and model)

# %%
class car :
  def __init__(self,brand,model):
    self.brand = brand
    self.model = model

  def full_name(self):
    return f"{self.brand}{self.model}"

my_car = car("Toyota ","Corolla")
print(my_car.full_name())
# Out:
# Toyota Corolla

# %% [markdown]
# #Inheritance
# Create an Electric car class that inherits from the car class and has an additional attribute battery_size.

# %%
class ElectricCar(car):
  def __init__(self,brand,model,battery_size):
    super().__init__(brand, model)            #super() is used to access classes used before
    self.battery_size = battery_size

my_electric_car = ElectricCar("Tesla","ModelS","85Kwh")
print(my_electric_car.brand)
print(my_electric_car.model)
print(my_electric_car.battery_size)
print(my_electric_car.full_name())
print(my_electric_car.full_name)
# Out:
# Tesla
# ModelS
# 85Kwh
# TeslaModelS
# <bound method car.full_name of <__main__.ElectricCar object at 0x7eca9f84f230>>

# %% [markdown]
# #Encapsulation
# Modify the car class to encapsulate the brand attribute, making in private, and provide a getter method for it.
#
# Its like an capsule - When ever we will want - we can access the codes within it ..

# %%
class car :
  def __init__(self,brand,model):
    self.__brand = brand
    self.model = model

  def get_brand(self):
    return self.__brand

class Tesla(car) : # Inherit from 'car' class
  def __init__(self,brand,model,battery_size):
    super().__init__(brand, model)
    self.battery_size = battery_size

  def get_brand(self):
    return self.get_brand(), self.model, self.battery_size


my_car = Tesla("Tesla","Model-S","85-KWH")
print(my_car.get_brand())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1262/1149136107.py in <cell line: 0>()
#      16
#      17
# ---> 18 my_car = Tesla("Tesla","Model-S","85-KWH")
#      19 print(my_car.__brand)
#      20 print(my_car.get_brand())
#
# /tmp/ipykernel_1262/1149136107.py in __init__(self, brand, model, battery_size)
#       9 class Tesla(car) : # Inherit from 'car' class
#      10   def __init__(self,brand,model,battery_size):
# ---> 11     super().__init__(__brand, model)
#      12     self.battery_size = battery_size
#      13
#
# NameError: name '_Tesla__brand' is not defined

# %% [markdown]
# <a href="https://colab.research.google.com/github/routparam12/Qns_solve_dsa/blob/main/Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tea_types = ("Black","Green","Oolong")

# %%
tea_types
tea_types[2]
# Out:
# 'Oolong'

# %%
tea_types[1]="Lemon"     #tuples are imutable so we canot change the the value we can only chane the reference of the object to another.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_227/2033861722.py in <cell line: 0>()
# ----> 1 tea_types[1]="Lemon"     #tuples are imutable so we canot change the the value we can only chane the reference of the object to another.
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(tea_types)
# Out:
# 3

# %%
more_tea=("Herbal","Earl_grey")
more_tea
# Out:
# ('Herbal', 'Earl_grey')

# %%
all_tea =tea_types + more_tea
all_tea
# Out:
# ('Black', 'Green', 'Oolong', 'Herbal', 'Earl_grey')

# %%
tea_types
type(tea_types)
# Out:
# tuple

# %%
(black, green, Oolong) = tea_types
black
# Out:
# 'Black'
